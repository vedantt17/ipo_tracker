# %%
# Written by V
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

conn = sqlite3.connect('../database/ipo_tracker.db')
df = pd.read_sql('SELECT * FROM ipo_summary', conn)
uw = pd.read_sql('SELECT * FROM underwriter_league', conn)
conn.close()

df_perf = df[df['return_90d'].notna()].copy()
df_perf['ipo_year'] = pd.to_datetime(df_perf['ipo_date']).dt.year
df_perf['return_90d_pct'] = df_perf['return_90d'] * 100

print(f'Full dataset: {len(df)} rows')
print(f'With return_90d: {len(df_perf)} rows')
print('Ready for analysis')
